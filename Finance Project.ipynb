# %% [markdown]
# # Finance Data Project
#
# In this data project I will focus on exploratory data analysis of stock prices.
# I will focus on bank stocks and see how they progressed throughout the financial crisis all the way to early 2016.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
#  I got stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

#Bank of America
BAC = data.DataReader("BAC", 'yahoo', start, end)

# CitiGroup
C = data.DataReader("C", 'yahoo', start, end)

# Goldman Sachs
GS = data.DataReader("GS", 'yahoo', start, end)

# JPMorgan Chase
JPM = data.DataReader("JPM", 'yahoo', start, end)

# Morgan Stanley
MS = data.DataReader("MS", 'yahoo', start, end)

# Wells Fargo
WFC = data.DataReader("WFC", 'yahoo', start, end)

# %% [markdown]
# ** Creating a list of the ticker symbols (as strings) in alphabetical order

# %%
tickers= ['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
#  concatenate the bank dataframes together to a single data frame called bank_stocks

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.969635
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.840177
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.978883
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.766198
# ...

# %%
bank_stock
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.969635
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.840177
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.978883
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.766198
# ...

# %%
bank_stocks.columns.names = ['Banks','Stock Info']

# %% [markdown]
# ** The max Close price for each bank's stock throughout the time period**

# %%
for bank in tickers: 
    print(bank , bank_stocks.loc[:,bank]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Banks
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
#creating an empty df that will hold data about stocks returns

# %%
returns=pd.DataFrame()

# %%
for bank in tickers: 
   returns[bank+ 'return'] = bank_stocks[bank]['Close'].pct_change()

# %%
returns
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn  WFCreturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158
# ...               ...       ...       ...        ...       ...        ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681  -0.003997
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544  -0.002554
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812   0.011156
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831  -0.007235
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031  -0.009656
#
# [2517 rows x 6 columns]

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe.

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
sns.pairplot(returns,dropna=True)

# %% [markdown]
# **  worst single day returns

# %%
returns.idxmin()
# Out:
# BACreturn   2009-01-20
# Creturn     2009-02-27
# GSreturn    2009-01-20
# JPMreturn   2009-01-20
# MSreturn    2008-10-09
# WFCreturn   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
#  **best  single day returns

# %%
returns.idxmax()
# Out:
# BACreturn   2009-04-09
# Creturn     2008-11-24
# GSreturn    2008-11-24
# JPMreturn   2009-01-21
# MSreturn    2008-10-13
# WFCreturn   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** The standard deviation of the returns for the year 2015 to classify as the riskiest

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BACreturn    0.016163
# Creturn      0.015289
# GSreturn     0.014046
# JPMreturn    0.014017
# MSreturn     0.016249
# WFCreturn    0.012591
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31','MSreturn']
# Out:
# Date
# 2015-01-02   -0.002320
# 2015-01-05   -0.031258
# 2015-01-06   -0.028800
# 2015-01-07    0.014278
# 2015-01-08    0.014889
#                 ...
# 2015-12-24   -0.003681
# 2015-12-28   -0.009544
# 2015-12-29    0.011812
# 2015-12-30   -0.009831
# 2015-12-31   -0.013031
# Name: MSreturn, Length: 252, dtype: float64

# %% [markdown]
# ** Create a distplot  of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31','MSreturn'],bins=100)

# %% [markdown]
# ** Create a distplot  of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31','MSreturn'],bins=100)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot(figsize=(12,4))

# %% [markdown]
# ## Moving Averages
#
# **Rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,6))
bank_stocks.loc['2008-01-01':'2008-12-31','BAC']['Close'].plot(title='BAC returns')
bank_stocks.loc['2008-01-01':'2008-12-31','BAC']['Close'].rolling(window=30).mean().plot(label='30 days avg')
plt.legend()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
